# %%
import pandas as pd

# %%
data = pd.read_csv("1000_Companies.csv")

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        1000 non-null   float64
#  1   Administration   1000 non-null   float64
#  2   Marketing Spend  1000 non-null   float64
#  3   State            1000 non-null   object
#  4   Profit           1000 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
#data understsnding
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count    1000.000000     1000.000000      1000.000000    1000.000000
# mean    81668.927200   122963.897612    226205.058419  119546.164656
# std     46537.567891    12613.927535     91578.393542   42888.633848
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     43084.500000   116640.684850    150969.584600   85943.198543
# 50%     79936.000000   122421.612150    224517.887350  117641.466300
# 75%    124565.500000   129139.118000    308189.808525  155577.107425
# max    165349.200000   321652.140000    471784.100000  476485.430000

# %%
#cheking eacha column

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data['R&D Spend'].describe()
# Out:
# count      1000.000000
# mean      81668.927200
# std       46537.567891
# min           0.000000
# 25%       43084.500000
# 50%       79936.000000
# 75%      124565.500000
# max      165349.200000
# Name: R&D Spend, dtype: float64

# %%
#visualizing the data in r&d against profit
plt.scatter(data['R&D Spend'],data['Profit'])
plt.title('scatter on R&D against profits')
plt.xlabel('R&D Spend')
plt.ylabel('profits')
plt.show();

# %%
plt.scatter(data['Administration'],data['Profit'])
plt.title('scatter on administration against profit')
plt.xlabel('administration')
plt.ylabel('profits')
plt.show();

# %%
plt.scatter(data['Marketing Spend'],data['Profit'])
plt.title("scatter on marketing spend against profit")
plt.xlabel("marketing spend")
plt.ylabel('profits')
plt.show();

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_128224/1217599898.py in <module>
# ----> 1 plt.bar(data['State'])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
#looking at the shape of the data
data.shape
# Out:
# (1000, 5)
